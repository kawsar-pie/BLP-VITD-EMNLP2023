# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import transformers
from transformers import AutoModelForSequenceClassification
from transformers import AutoModel

# %% [markdown]
# # API Call (mBERT)

# %% [markdown]
# ### Using Model1 [Violence(1) vs non-violence(0)]

# %%
from transformers import AutoTokenizer, pipeline
import torch
import pandas as pd

# Load tokenizer and model
model = pipeline("text-classification", model="ka05ar/bert-base-multilingual-cased-VITD-m1", tokenizer="ka05ar/bert-base-multilingual-cased-VITD-m1")

# Load your data
data = pd.read_csv("/kaggle/input/emnlp20230-task1/test.csv", encoding='utf8')
texts = data["text"].tolist()

# Pass the texts to the model for classification
with torch.no_grad():
    predictions = model(texts)

# Get predicted probabilities and labels
predicted_labels = [pred['label'] for pred in predictions]
probs = [pred['score'] for pred in predictions]

# Create new columns in the DataFrame
data['predicted_label'] = predicted_labels
data['predicted_probability'] = probs

# %%
data

# %%
data['label'] = data['predicted_label'].apply(lambda x: 1 if x=='LABEL_1' else 0)

# %%
data

# %%
data.to_csv("test_predicted_results_m1.csv", index=False)

# %% [markdown]
# ### Using Model2 [Passive Violence(0-->1) vs Direct-violence(1-->2)]

# %%
data

# %%
violent_only_data = data.copy()

# %%
violent_only_data = violent_only_data[violent_only_data['label']==1]

# %%
violent_only_data

# %%
violent_only_data = violent_only_data.drop(["predicted_label","predicted_probability","label"],axis=1)

# %%
violent_only_data

# %%
from transformers import AutoTokenizer, pipeline
import torch
import pandas as pd

# Load tokenizer and model
model = pipeline("text-classification", model="ka05ar/bert-base-multilingual-cased-VITD-m2", tokenizer="ka05ar/bert-base-multilingual-cased-VITD-m2")

# Load your data
# data = pd.read_csv("/kaggle/input/emnlp20230-task1/test.csv", encoding='utf8')
texts = violent_only_data["text"].tolist()

# Pass the texts to the model for classification
with torch.no_grad():
    predictions = model(texts)

# Get predicted probabilities and labels
predicted_labels = [pred['label'] for pred in predictions]
probs = [pred['score'] for pred in predictions]

# Create new columns in the DataFrame
violent_only_data['predicted_label'] = predicted_labels
violent_only_data['predicted_probability'] = probs

# Save the modified DataFrame to a new CSV file

# Print results
# for i, (predicted_label, prob) in enumerate(zip(predicted_labels, probs)):
#     print(f"Text: {texts[i]}")
#     print(f"Predicted Label: {predicted_label}")
#     print(f"Predicted Probability: {prob}")
#     print()

# %%
violent_only_data.head(20)
# Out:
#                                                  text predicted_label  \
# 0   বাংলাদেশের হিন্দুরা নিজেদের জন্য আলাদা হিন্দু ...         LABEL_1
# 1   মাইজদী - চৌমুহুনী - ফেনী মন্দিরে হামলা নিয়ে রি...         LABEL_1
# 2   দয়া করে পবিত্র কুরআনুল কারিম বলেন,,,,পবিত্র কথ...         LABEL_1
# 3   বিবিসি হলো সত্য কে বিনষ্টকারী আর মিথ্যা কে গ্র...         LABEL_0
# 9           কোরান অবমাননা না বলে পাওয়া গেছে বলেন কেন?         LABEL_0
# 10                            কাদের কাকা গুজব কোন টা।         LABEL_0
# 12  কুরআনকে যখন অবমাননা করা হলো আপনারা একটা নিউজ ক...         LABEL_0
# 13      মিথ্যা বাদি ওবাইদেরকাদের কথা বিশ্বাস করবেন না         LABEL_0
# 14  একটি মহল দেশে আন্দলন করবে বলে হুমকি দমকি দিচ্ছ...         LABEL_0
# 16  ৪-৫ জন লোককে নির্বিচারে হত্যা করছে এ নিয়ে ভারত...         LABEL_0
# 17  স্ফুলিঙ্গ যখন সৃষ্টি হলো, তখন সেটা শুরুতেই পদক...         LABEL_0
# 19  সরকার এরকম তো বহুতে আশ্বাস দেয় বালের মাথা কিছু...         LABEL_0
# 22  ভাই বিবিসি নিউজ বলে চেনেল টা সাব্চক্রাইব করেছি...         LABEL_0
# 24       সত্য প্রচার করতে ভয় পাশ নাকি। দালালের দল,,,,         LABEL_0
# 25  সুন্দর প্রত্যেকের জন্য কুরআন ও কুরআন শেখে হিন্...         LABEL_0
# 26  কোরআন অবমাননার খবর কই। কোরআন পাওয়া রে পাগল কোর...         LABEL_0
# 28  আমি এখানে মুসলিম ভাইদের বলবো গালাগালি না করে,,...         LABEL_0
# 30  যে মন্দীরে কুরআন কে অপমান করা হইছে সেই মন্দীরক...         LABEL_1
# 36  কালকে ভারতের মসজিদে মুর্তির ভাঙ্গা টুকরা পাওয়া...         LABEL_1
# 40  ওহাইরে পুলিশ তুমরা এত নিরপেক্ষ বাংলাদেশ সিংগাপ...         LABEL_0
#
#     predicted_probability
# 0                0.800037
# 1                0.744920
# 2                0.579918
# 3                0.884961
# 9                0.950248
# 10               0.694401
# 12               0.933148
# 13               0.928031
# 14               0.917557
# 16               0.937356
# 17               0.703145
# 19               0.924474
# 22               0.879441
# 24               0.890404
# 25               0.779061
# 26               0.774449
# 28               0.611051
# 30               0.743469
# 36               0.800266
# 40               0.772972

# %%
violent_only_data['label'] = violent_only_data['predicted_label'].apply(lambda x: 2 if x=='LABEL_1' else 1)

# %%
violent_only_data.head(20)
# Out:
#                                                  text predicted_label  \
# 0   বাংলাদেশের হিন্দুরা নিজেদের জন্য আলাদা হিন্দু ...         LABEL_1
# 1   মাইজদী - চৌমুহুনী - ফেনী মন্দিরে হামলা নিয়ে রি...         LABEL_1
# 2   দয়া করে পবিত্র কুরআনুল কারিম বলেন,,,,পবিত্র কথ...         LABEL_1
# 3   বিবিসি হলো সত্য কে বিনষ্টকারী আর মিথ্যা কে গ্র...         LABEL_0
# 9           কোরান অবমাননা না বলে পাওয়া গেছে বলেন কেন?         LABEL_0
# 10                            কাদের কাকা গুজব কোন টা।         LABEL_0
# 12  কুরআনকে যখন অবমাননা করা হলো আপনারা একটা নিউজ ক...         LABEL_0
# 13      মিথ্যা বাদি ওবাইদেরকাদের কথা বিশ্বাস করবেন না         LABEL_0
# 14  একটি মহল দেশে আন্দলন করবে বলে হুমকি দমকি দিচ্ছ...         LABEL_0
# 16  ৪-৫ জন লোককে নির্বিচারে হত্যা করছে এ নিয়ে ভারত...         LABEL_0
# 17  স্ফুলিঙ্গ যখন সৃষ্টি হলো, তখন সেটা শুরুতেই পদক...         LABEL_0
# 19  সরকার এরকম তো বহুতে আশ্বাস দেয় বালের মাথা কিছু...         LABEL_0
# 22  ভাই বিবিসি নিউজ বলে চেনেল টা সাব্চক্রাইব করেছি...         LABEL_0
# 24       সত্য প্রচার করতে ভয় পাশ নাকি। দালালের দল,,,,         LABEL_0
# 25  সুন্দর প্রত্যেকের জন্য কুরআন ও কুরআন শেখে হিন্...         LABEL_0
# 26  কোরআন অবমাননার খবর কই। কোরআন পাওয়া রে পাগল কোর...         LABEL_0
# 28  আমি এখানে মুসলিম ভাইদের বলবো গালাগালি না করে,,...         LABEL_0
# 30  যে মন্দীরে কুরআন কে অপমান করা হইছে সেই মন্দীরক...         LABEL_1
# 36  কালকে ভারতের মসজিদে মুর্তির ভাঙ্গা টুকরা পাওয়া...         LABEL_1
# 40  ওহাইরে পুলিশ তুমরা এত নিরপেক্ষ বাংলাদেশ সিংগাপ...         LABEL_0
#
#     predicted_probability  label
# 0                0.800037      2
# 1                0.744920      2
# 2                0.579918      2
# 3                0.884961      1
# 9                0.950248      1
# 10               0.694401      1
# 12               0.933148      1
# 13               0.928031      1
# 14               0.917557      1
# 16               0.937356      1
# 17               0.703145      1
# 19               0.924474      1
# 22               0.879441      1
# 24               0.890404      1
# 25               0.779061      1
# 26               0.774449      1
# 28               0.611051      1
# 30               0.743469      2
# 36               0.800266      2
# 40               0.772972      1

# %%
violent_only_data = violent_only_data.drop(["predicted_label","predicted_probability"],axis=1)

# %%
violent_only_data.head(20)
# Out:
#                                                  text  label
# 0   বাংলাদেশের হিন্দুরা নিজেদের জন্য আলাদা হিন্দু ...      2
# 1   মাইজদী - চৌমুহুনী - ফেনী মন্দিরে হামলা নিয়ে রি...      2
# 2   দয়া করে পবিত্র কুরআনুল কারিম বলেন,,,,পবিত্র কথ...      2
# 3   বিবিসি হলো সত্য কে বিনষ্টকারী আর মিথ্যা কে গ্র...      1
# 9           কোরান অবমাননা না বলে পাওয়া গেছে বলেন কেন?      1
# 10                            কাদের কাকা গুজব কোন টা।      1
# 12  কুরআনকে যখন অবমাননা করা হলো আপনারা একটা নিউজ ক...      1
# 13      মিথ্যা বাদি ওবাইদেরকাদের কথা বিশ্বাস করবেন না      1
# 14  একটি মহল দেশে আন্দলন করবে বলে হুমকি দমকি দিচ্ছ...      1
# 16  ৪-৫ জন লোককে নির্বিচারে হত্যা করছে এ নিয়ে ভারত...      1
# 17  স্ফুলিঙ্গ যখন সৃষ্টি হলো, তখন সেটা শুরুতেই পদক...      1
# 19  সরকার এরকম তো বহুতে আশ্বাস দেয় বালের মাথা কিছু...      1
# 22  ভাই বিবিসি নিউজ বলে চেনেল টা সাব্চক্রাইব করেছি...      1
# 24       সত্য প্রচার করতে ভয় পাশ নাকি। দালালের দল,,,,      1
# 25  সুন্দর প্রত্যেকের জন্য কুরআন ও কুরআন শেখে হিন্...      1
# 26  কোরআন অবমাননার খবর কই। কোরআন পাওয়া রে পাগল কোর...      1
# 28  আমি এখানে মুসলিম ভাইদের বলবো গালাগালি না করে,,...      1
# 30  যে মন্দীরে কুরআন কে অপমান করা হইছে সেই মন্দীরক...      2
# 36  কালকে ভারতের মসজিদে মুর্তির ভাঙ্গা টুকরা পাওয়া...      2
# 40  ওহাইরে পুলিশ তুমরা এত নিরপেক্ষ বাংলাদেশ সিংগাপ...      1

# %%
# Assuming df_original and df_changed have been defined

# Update only the rows with changed label values
changed_indices = violent_only_data.index
data.loc[changed_indices, 'label'] = violent_only_data['label']

# %%
data.head(20)
# Out:
#                                                  text predicted_label  \
# 0   বাংলাদেশের হিন্দুরা নিজেদের জন্য আলাদা হিন্দু ...         LABEL_1
# 1   মাইজদী - চৌমুহুনী - ফেনী মন্দিরে হামলা নিয়ে রি...         LABEL_1
# 2   দয়া করে পবিত্র কুরআনুল কারিম বলেন,,,,পবিত্র কথ...         LABEL_1
# 3   বিবিসি হলো সত্য কে বিনষ্টকারী আর মিথ্যা কে গ্র...         LABEL_1
# 4             বুধবার কি তোরা মারা গেছিলি বিবিসি বাংলা         LABEL_0
# 5   কোরআন পাওয়া গেছে, কোরআন পাওয়া গেছে,যেমন ভাবে ব...         LABEL_0
# 6   কোরআন কে কেন অবমাননা করা হল? মুসলিমরা কি দোষ ক...         LABEL_0
# 7   আমরা হিন্দু রা কুরআন পূজা করি না। এটা সম্পূর্ণ...         LABEL_0
# 8   সন্চালককে বলতে চাই কথাটি হবে দেব দেবীর পায়ে কো...         LABEL_0
# 9           কোরান অবমাননা না বলে পাওয়া গেছে বলেন কেন?         LABEL_1
# 10                            কাদের কাকা গুজব কোন টা।         LABEL_1
# 11  মাননীয় মন্ত্রী অসাম্প্রদায়িক ব্যাক্তি কারা একট...         LABEL_0
# 12  কুরআনকে যখন অবমাননা করা হলো আপনারা একটা নিউজ ক...         LABEL_1
# 13      মিথ্যা বাদি ওবাইদেরকাদের কথা বিশ্বাস করবেন না         LABEL_1
# 14  একটি মহল দেশে আন্দলন করবে বলে হুমকি দমকি দিচ্ছ...         LABEL_1
# 15  হুম।মানুষের বুকের রক্ত নিয়েই তো আজকে ইসলাম প্র...         LABEL_0
# 16  ৪-৫ জন লোককে নির্বিচারে হত্যা করছে এ নিয়ে ভারত...         LABEL_1
# 17  স্ফুলিঙ্গ যখন সৃষ্টি হলো, তখন সেটা শুরুতেই পদক...         LABEL_1
# 18  এটাকে গুজব কেন বলে আমি বুজলাম না, ঘটনা কি সত্য...         LABEL_0
# 19  সরকার এরকম তো বহুতে আশ্বাস দেয় বালের মাথা কিছু...         LABEL_1
#
#     predicted_probability  label
# 0                0.758350      2
# 1                0.995502      2
# 2                0.895386      2
# 3                0.943791      1
# 4                0.997922      0
# 5                0.997628      0
# 6                0.998880      0
# 7                0.999370      0
# 8                0.998670      0
# 9                0.999362      1
# 10               0.998292      1
# 11               0.999128      0
# 12               0.999476      1
# 13               0.877125      1
# 14               0.645372      1
# 15               0.998239      0
# 16               0.999463      1
# 17               0.999245      1
# 18               0.999105      0
# 19               0.999354      1

# %%
data.shape
# Out:
# (2016, 4)

# %%
data = data.drop(['predicted_label',"predicted_probability"],axis=1)

# %%
data.head(20)
# Out:
#                                                  text  label
# 0   বাংলাদেশের হিন্দুরা নিজেদের জন্য আলাদা হিন্দু ...      2
# 1   মাইজদী - চৌমুহুনী - ফেনী মন্দিরে হামলা নিয়ে রি...      2
# 2   দয়া করে পবিত্র কুরআনুল কারিম বলেন,,,,পবিত্র কথ...      2
# 3   বিবিসি হলো সত্য কে বিনষ্টকারী আর মিথ্যা কে গ্র...      1
# 4             বুধবার কি তোরা মারা গেছিলি বিবিসি বাংলা      0
# 5   কোরআন পাওয়া গেছে, কোরআন পাওয়া গেছে,যেমন ভাবে ব...      0
# 6   কোরআন কে কেন অবমাননা করা হল? মুসলিমরা কি দোষ ক...      0
# 7   আমরা হিন্দু রা কুরআন পূজা করি না। এটা সম্পূর্ণ...      0
# 8   সন্চালককে বলতে চাই কথাটি হবে দেব দেবীর পায়ে কো...      0
# 9           কোরান অবমাননা না বলে পাওয়া গেছে বলেন কেন?      1
# 10                            কাদের কাকা গুজব কোন টা।      1
# 11  মাননীয় মন্ত্রী অসাম্প্রদায়িক ব্যাক্তি কারা একট...      0
# 12  কুরআনকে যখন অবমাননা করা হলো আপনারা একটা নিউজ ক...      1
# 13      মিথ্যা বাদি ওবাইদেরকাদের কথা বিশ্বাস করবেন না      1
# 14  একটি মহল দেশে আন্দলন করবে বলে হুমকি দমকি দিচ্ছ...      1
# 15  হুম।মানুষের বুকের রক্ত নিয়েই তো আজকে ইসলাম প্র...      0
# 16  ৪-৫ জন লোককে নির্বিচারে হত্যা করছে এ নিয়ে ভারত...      1
# 17  স্ফুলিঙ্গ যখন সৃষ্টি হলো, তখন সেটা শুরুতেই পদক...      1
# 18  এটাকে গুজব কেন বলে আমি বুজলাম না, ঘটনা কি সত্য...      0
# 19  সরকার এরকম তো বহুতে আশ্বাস দেয় বালের মাথা কিছু...      1

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

# %%
preds = data['label']

# %%
original_output = pd.read_csv("/kaggle/input/emnlp-2023-task1-test/test_task1.csv",encoding='utf8')
labels = original_output['label']

# %%
macro_f1 = f1_score(labels, preds, average="macro")

# %%
macro_f1
# Out:
# 0.6190430950753644

# %%
acc = accuracy_score(labels,preds)
acc
# Out:
# 0.6815476190476191

# %%
precision = precision_score(labels, preds,average="macro")
precision
# Out:
# 0.6152501307140509

# %%
recall = recall_score(labels, preds,average="macro")
recall
# Out:
# 0.6573225270188586

# %%
macro_f1, acc, precision, recall
# Out:
# (0.6190430950753644,
#  0.6815476190476191,
#  0.6152501307140509,
#  0.6573225270188586)

# %%
acc, precision, recall, macro_f1
# Out:
# (0.6815476190476191,
#  0.6152501307140509,
#  0.6573225270188586,
#  0.6190430950753644)
